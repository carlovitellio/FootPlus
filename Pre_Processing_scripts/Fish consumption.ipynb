# %%
import pandas as pd

# %%
df = pd.read_csv('../Raw_Data/OECD_FAO_data/HIGH_AGLINK_2020_22052021164251928.csv')
df
# Out:
#        LOCATION         Country COMMODITY Commodity VARIABLE  \
# 0          OECD  OECD countries        WT     Wheat       QP
# 1          OECD  OECD countries        WT     Wheat       QP
# 2          OECD  OECD countries        WT     Wheat       QP
# 3          OECD  OECD countries        WT     Wheat       QP
# 4          OECD  OECD countries        WT     Wheat       QP
# ...         ...             ...       ...       ...      ...
# 107024      WLD           WORLD       MOL  Molasses       PC
# 107025      WLD           WORLD       MOL  Molasses       PC
# 107026      WLD           WORLD       MOL  Molasses       PC
# 107027      WLD           WORLD       MOL  Molasses       PC
# 107028      WLD           WORLD       MOL  Molasses       PC
#
#                             Variable  TIME  Time Unit Code  \
# 0                         Production  2010  2010     TONNE
# 1                         Production  2011  2011     TONNE
# ...

# %%
df['Commodity'].unique()
# Out:
# array(['Wheat', 'Maize', 'Other coarse grains', 'Rice',
#        "Distiller's dry grains", 'Soybean', 'Other oilseeds',
#        'Protein meals', 'Vegetable oils', 'Molasses', 'Sugar',
#        'Raw sugar', 'White sugar', 'High fructose corn syrup',
#        'Sugar beet', 'Sugar cane', 'Beef and veal', 'Pigmeat',
#        'Poultry meat', 'Sheepmeat', 'Milk', 'Fresh dairy products',
#        'Butter', 'Cheese', 'Skim milk powder', 'Whole milk powder',
#        'Whey powder', 'Casein', 'Ethanol', 'Biodiesel', 'Fish',
#        'Fish from capture', 'Fish from aquaculture', 'Fish meal',
#        'Fish oil', 'COTTON', 'ROOTS AND TUBERS', 'PULSES', 'Fertilizer',
#        'Oil'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['OECD countries', 'Turkey', 'United States', 'NORTH AMERICA',
#        'EUROPE', 'Russian Federation', 'Ukraine', 'AFRICA',
#        'South Africa', 'LATIN AMERICA', 'Paraguay', 'ASIA',
#        'Saudi Arabia', 'Thailand', 'Viet Nam', 'WORLD'], dtype=object)

# %%
column_list = ['Fish']

# %%
df = df[(df['Country'].str.contains('WORLD'))  &  (df['Commodity'].isin(column_list)) & (df['Variable'].str.contains('Consumption'))]
df
# Out:
#       LOCATION Country COMMODITY Commodity VARIABLE     Variable  TIME  Time  \
# 57680      WLD   WORLD        FH      Fish       QC  Consumption  2010  2010
# 57681      WLD   WORLD        FH      Fish       QC  Consumption  2011  2011
# 57682      WLD   WORLD        FH      Fish       QC  Consumption  2012  2012
# 57683      WLD   WORLD        FH      Fish       QC  Consumption  2013  2013
# 57684      WLD   WORLD        FH      Fish       QC  Consumption  2014  2014
# 57685      WLD   WORLD        FH      Fish       QC  Consumption  2015  2015
# 57686      WLD   WORLD        FH      Fish       QC  Consumption  2016  2016
# 57687      WLD   WORLD        FH      Fish       QC  Consumption  2017  2017
# 57688      WLD   WORLD        FH      Fish       QC  Consumption  2018  2018
# 57689      WLD   WORLD        FH      Fish       QC  Consumption  2019  2019
# 57690      WLD   WORLD        FH      Fish       QC  Consumption  2020  2020
# ...

# %%
df.to_csv('../Preprocessed_data/Flourish_data/total_world_fish_consumption.csv')
